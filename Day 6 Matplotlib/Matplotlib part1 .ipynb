# %%
import pandas as pd

# %%
data = pd.read_csv('test.csv')
data.head()
# Out:
#    Unnamed: 0   SHOP_DATE  SPEND
# 0           0  2007-10-06   0.37
# 1           1  2007-02-01   5.08
# 2           2  2007-11-03   2.36
# 3           3  2007-02-06   0.20
# 4           4  2007-10-15   1.65

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# SHOP_DATE      object
# SHOP_HOUR       int64
# BASKET_ID     float64
# CUST_CODE      object
# STORE_CODE     object
# PROD_CODE      object
# QUANTITY        int64
# SPEND         float64
# Month          object
# Month_num       int64
# DAY            object
# dtype: object

# %%
# import library  matplotlib
import matplotlib.pyplot as plt

# %%
# bar plot 
fig, ax = plt.subplots(figsize = (10,8))
ax.bar(data['SHOP_HOUR'], data['QUANTITY'])
plt.show()

# %%
#time series
fig , ax = plt.subplots(figsize =(15,20))
ax.plot (data.SHOP_DATE)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-71a8c3022e21> in <module>
# ----> 1 data.index.head()
#
# AttributeError: 'RangeIndex' object has no attribute 'head'
